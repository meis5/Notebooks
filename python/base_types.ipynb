# %%
import sys
print sys.version
# Out:
# 2.7.13 (default, Mar  9 2017, 10:57:50)
# [GCC 4.2.1 Compatible Apple LLVM 8.0.0 (clang-800.0.42.1)]

# %%
import numpy as np

np.sqrt(4)
# Out:
# 2.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(100)
plt.plot(x)
plt.show()
